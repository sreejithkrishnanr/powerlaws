# %%
import pandas as pd
import numpy as np

from matplotlib.pyplot import rcParams
rcParams['figure.figsize'] = (18.0, 10.0)
import matplotlib.pyplot as plt

import seaborn as sns
sns.set()

from tqdm import tqdm

# %%
dataset = pd.read_csv('../data/processed/train_86400000000000.csv', parse_dates=[1])
# dataset = dataset.loc[dataset['SiteId'] == 1, :]
dataset.shape
# Out:
# (52830, 69)

# %%
(dataset.groupby('SiteId')['HasTemperature'].sum()/dataset.groupby('SiteId')['HasTemperature'].count()).plot(kind='bar')

# %%
dataset.set_index('Timestamp')[['Consumption', 'Consumption', 'TemperatureMeanDiff']].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a16741eb8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a1885c780>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a176ab208>],
#       dtype=object)

# %%
dataset.keys()
# Out:
# Index(['ForecastId', 'Timestamp', 'obs_id', 'SiteId', 'Value', 'Frequency',
#        'DayOfMonth', 'DayOfWeek', 'DayOfYear', 'DaysInMonth', 'Hour',
#        'IsLeapYear', 'IsMonthEnd', 'IsMonthStart', 'IsQuarterEnd',
#        'IsQuarterStart', 'IsYearEnd', 'IsYearStart', 'Minute', 'Month',
#        'Quarter', 'WeekOfYear', 'DayOfMonth_cos', 'DayOfMonth_sin',
#        'DayOfWeek_cos', 'DayOfWeek_sin', 'DaysInYear', 'DayOfYear_cos',
#        'DayOfYear_sin', 'Hour_cos', 'Hour_sin', 'Minute_cos', 'Minute_sin',
#        'Month_cos', 'Month_sin', 'Quarter_cos', 'Quarter_sin',
#        'WeekOfYear_cos', 'WeekOfYear_sin', 'IsSpecialHoliday', 'IsWeekend',
#        'IsHoliday', 'DistanceMean', 'DistanceVariance', 'NumStations',
#        'TemperatureMean', 'TemperatureVariance', 'TemperatureMin',
#        'TemperatureMax', 'HasTemperature', 'SamplingRate', 'BaseTemperature',
#        'SurfaceArea', 'TemperatureMeanDiff', 'TemperatureMinDiff',
#        'TemperatureMaxDiff', 'Consumption', 'ConsumptionPerSurfaceArea',
#        'ConsumptionPerTemperatureDiff'],
#       dtype='object')

# %%
features = [
    'IsMonthEnd', 'IsQuarterEnd', 'IsQuarterStart', 'IsYearEnd', 'IsYearStart', 'DayOfMonth_cos', 
    'DayOfMonth_sin', 'Quarter_cos', 'Quarter_sin', 'WeekOfYear_cos', 'WeekOfYear_sin', 'IsSpecialHoliday', 'IsWeekend',
    'IsHoliday', 'DistanceMean', 'DistanceVariance', 'NumStations', 'TemperatureMeanDiff', 'TemperatureVariance', 
    'TemperatureMinDiff', 'TemperatureMaxDiff', 'HasTemperature', 'Consumption'
]

ts = dataset[features]

# %%
ts_x = ts.drop(columns=['Consumption'])
ts_y = ts['Consumption']
ts_fids = dataset['ForecastId']

ts_fids.value_counts()
# Out:
# 3    360
# 1    360
# 4     90
# 2     90
# Name: ForecastId, dtype: int64

# %%
import math

input_window_size = 75
output_window_size = 59
frequency = np.timedelta64(1, 'D')

# %%
def generate_test_train_split(x, y, forecast_ids, input_window_size, output_window_size, test_size=1):
    min_test_size = (input_window_size + output_window_size) * 2
    fids, counts = np.unique(forecast_ids, return_counts=True)
    
    num_forecasts_for_test = round(fids.shape[0]*test_size)
    testable_fids = fids[np.where(counts >= min_test_size)]
    
    test_fids = np.random.choice(testable_fids, num_forecasts_for_test)
    
    test_mask = np.repeat([False], forecast_ids.shape[0])
    
    test_size = input_window_size + output_window_size
    for fid in test_fids:
        indices,  = np.where(forecast_ids == fid)
        test_mask[indices[-test_size:]] = True
            
    train_mask = np.logical_not(test_mask)
    
    return x[train_mask], y[train_mask], forecast_ids[train_mask], x[test_mask], y[test_mask], forecast_ids[test_mask]
    
ts_xtrain, ts_ytrain, ts_ftrain, ts_xtest, ts_ytest, ts_ftest = generate_test_train_split(ts_x, ts_y, ts_fids, input_window_size, output_window_size)

print(ts_xtrain.shape, ts_ytrain.shape)
print(ts_xtest.shape, ts_xtest.shape)
# Out:
# (632, 22) (632,)
# (268, 22) (268, 22)

# %%
def generate_train_forecast_ts(x, y, input_window_size, output_window_size, pad=True):
    assert x.shape[0] == y.shape[0]
    
    min_size = input_window_size + output_window_size
    input_size = x.shape[0]
    
    if input_size < min_size and pad:
        num_pads = min_size - input_size
        
        x_pad = np.zeros((num_pads, x.shape[1]))
        y_pad = np.zeros((num_pads, y.shape[1]))
        x = np.vstack((x_pad, x))
        y = np.vstack((y_pad, y))
        
    assert x.shape[0] >= min_size
        
    num_samples = x.shape[0] - input_window_size - output_window_size + 1
    
    x_res = []
    y_res = []

    for i in range(num_samples):
        x_t = np.hstack((x[i:i + input_window_size], y[i:i + input_window_size].reshape(-1, 1)))

        x_t_plus_1 = x[i + input_window_size:i + input_window_size + output_window_size]
        y_t_plus_1 = y[i + input_window_size:i + input_window_size + output_window_size]

        x_res.append(np.concatenate((x_t.ravel(), x_t_plus_1.ravel())))
        y_res.append(y_t_plus_1)

    return np.array(x_res), np.array(y_res)


def generate_train_ts(x, y, forecast_ids, input_window_size, output_window_size):
    assert x.shape[0] == y.shape[0]
    assert y.shape[0] == forecast_ids.shape[0]
    
    ids = np.unique(forecast_ids)
    
    agg_x = []
    agg_y = []
    for fid in tqdm(ids):
        fx = x[forecast_ids == fid, :]
        fy = y[forecast_ids == fid, :]
                
        fx_res , fy_res = generate_train_forecast_ts(fx, fy, input_window_size, output_window_size)
        
        agg_x.append(fx_res)
        agg_y.append(fy_res)
        
    agg_x = np.concatenate(agg_x)
    agg_y = np.concatenate(agg_y)
    agg_x = agg_x.reshape((agg_x.shape[0], 1, agg_x.shape[1]))
    agg_y = agg_y.reshape((agg_y.shape[0], 1, agg_y.shape[1]))
    
    return agg_x, agg_y

# %%
from sklearn.preprocessing import StandardScaler

scaler_x = StandardScaler()
scaler_y = StandardScaler()


tx_train, ty_train = generate_train_ts(
    scaler_x.fit_transform(ts_xtrain.values), 
    scaler_y.fit_transform(ts_ytrain.values.reshape(-1, 1)), 
    ts_ftrain.values, 
    input_window_size, output_window_size
)

tx_test, ty_test = generate_train_ts(
    scaler_x.transform(ts_xtest.values),
    scaler_y.transform(ts_ytest.values.reshape(-1, 1)),
    ts_ftest.values,
    input_window_size, output_window_size
)
# Out:
# /Users/sreejithkrishnanr/Tools/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 4/4 [00:00<00:00, 503.59it/s]
# 100%|██████████| 2/2 [00:00<00:00, 5745.62it/s]

# %%
from keras.layers import Dense, LSTM, TimeDistributed, Dropout
from keras.models import Sequential

def build_model(x_train, y_train):
    model = Sequential()
    model.add(LSTM(units=125, return_sequences=True, input_shape=(1, x_train.shape[2])))
#     model.add(Dropout(0.2))
    model.add(LSTM(units=125, return_sequences=True))
#     model.add(Dropout(0.2))
    model.add(TimeDistributed(Dense(units=y_train.shape[2], activation='linear')))
    model.compile(loss='mse', optimizer='adam')

    return model

model = build_model(tx_train, ty_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-dda2649b1115> in <module>()
#      13     return model
#      14
# ---> 15 model = build_model(tx_train, ty_train)
#
# <ipython-input-17-dda2649b1115> in build_model(x_train, y_train)
#       4 def build_model(x_train, y_train):
#       5     model = Sequential()
# ----> 6     model.add(LSTM(units=125, return_sequences=True, input_shape=(1, x_train.shape[2]), unroll=True))
#       7 #     model.add(Dropout(0.2))
#       8     model.add(LSTM(units=125, return_sequences=True, unroll=True))
#
# ~/Tools/anaconda3/lib/python3.6/site-packages/keras/models.py in add(self, layer)
#     465                 # and create the node connecting the current layer
#     466                 # to the input layer we just created.
# --> 467                 layer(x)
#     468
#     469             if len(layer._inbound_nodes[-1].output_tensors) != 1:
#
# ~/Tools/anaconda3/lib/python3.6/site-packages/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     497
#     498         if initial_state is None and constants is None:
# --> 499             return super(RNN, self).__call__(inputs, **kwargs)
#     500
#     501         # If any of `initial_state` or `constants` are specified and are Keras
#
# ~/Tools/anaconda3/lib/python3.6/site-packages/keras/engine/topology.py in __call__(self, inputs, **kwargs)
#     617
#     618             # Actually call the layer, collecting output(s), mask(s), and shape(s).
# --> 619             output = self.call(inputs, **kwargs)
#     620             output_mask = self.compute_mask(inputs, previous_mask)
#     621
#
# ~/Tools/anaconda3/lib/python3.6/site-packages/keras/layers/recurrent.py in call(self, inputs, mask, training, initial_state)
#    2149                                       mask=mask,
#    2150                                       training=training,
# -> 2151                                       initial_state=initial_state)
#    2152
#    2153     @property
#
# ~/Tools/anaconda3/lib/python3.6/site-packages/keras/layers/recurrent.py in call(self, inputs, mask, training, initial_state, constants)
#     570         timesteps = input_shape[1]
#     571         if self.unroll and timesteps in [None, 1]:
# --> 572             raise ValueError('Cannot unroll a RNN if the '
#     573                              'time dimension is undefined or equal to 1. \n'
#     574                              '- If using a Sequential model, '
#
# ValueError: Cannot unroll a RNN if the time dimension is undefined or equal to 1.
# - If using a Sequential model, specify the time dimension by passing an `input_shape` or `batch_input_shape` argument to your first layer. If your first layer is an Embedding, you can also use the `input_length` argument.
# - If using the functional API, specify the time dimension by passing a `shape` or `batch_shape` argument to your Input layer.

# %%
model.fit(tx_train, ty_train, validation_data=(tx_test, ty_test), epochs=100)
# Out:
# Train on 188 samples, validate on 2 samples
# Epoch 1/100
# 188/188 [==============================] - 2s 10ms/step - loss: 0.8684 - val_loss: 1.4269
# Epoch 2/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.7354 - val_loss: 1.6315
# Epoch 3/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.6032 - val_loss: 1.9412
# Epoch 4/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4820 - val_loss: 2.3340
# Epoch 5/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3949 - val_loss: 2.5539
# Epoch 6/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3305 - val_loss: 2.6533
# Epoch 7/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.2823 - val_loss: 2.5527
# Epoch 8/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.2480 - val_loss: 2.5018
# Epoch 9/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.2234 - val_loss: 2.5576
# Epoch 10/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.2066 - val_loss: 2.5375
# Epoch 11/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1913 - val_loss: 2.5582
# Epoch 12/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1786 - val_loss: 2.5193
# Epoch 13/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1669 - val_loss: 2.4195
# Epoch 14/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1560 - val_loss: 2.6025
# Epoch 15/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1461 - val_loss: 2.5546
# Epoch 16/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1369 - val_loss: 2.4974
# Epoch 17/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1277 - val_loss: 2.5125
# Epoch 18/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1201 - val_loss: 2.4865
# Epoch 19/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1128 - val_loss: 2.4924
# Epoch 20/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1066 - val_loss: 2.4358
# Epoch 21/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1007 - val_loss: 2.4960
# Epoch 22/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0949 - val_loss: 2.4996
# Epoch 23/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0903 - val_loss: 2.5995
# Epoch 24/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0855 - val_loss: 2.5108
# Epoch 25/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0818 - val_loss: 2.5961
# Epoch 26/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0781 - val_loss: 2.6057
# Epoch 27/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0752 - val_loss: 2.6584
# Epoch 28/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0718 - val_loss: 2.5334
# Epoch 29/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0695 - val_loss: 2.6291
# Epoch 30/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0669 - val_loss: 2.7003
# Epoch 31/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0642 - val_loss: 2.6889
# Epoch 32/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0619 - val_loss: 2.7240
# Epoch 33/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0597 - val_loss: 2.5724
# Epoch 34/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0580 - val_loss: 2.6735
# Epoch 35/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0557 - val_loss: 2.6677
# Epoch 36/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0535 - val_loss: 2.6220
# Epoch 37/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0522 - val_loss: 2.5993
# Epoch 38/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0503 - val_loss: 2.6025
# Epoch 39/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0489 - val_loss: 2.6108
# Epoch 40/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0477 - val_loss: 2.6392
# Epoch 41/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 2.6352
# Epoch 42/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0448 - val_loss: 2.6358
# Epoch 43/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0436 - val_loss: 2.5989
# Epoch 44/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0424 - val_loss: 2.6021
# Epoch 45/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0416 - val_loss: 2.6360
# Epoch 46/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0406 - val_loss: 2.5652
# Epoch 47/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0395 - val_loss: 2.5870
# Epoch 48/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0384 - val_loss: 2.5672
# Epoch 49/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0374 - val_loss: 2.7286
# Epoch 50/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0363 - val_loss: 2.5803
# Epoch 51/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0354 - val_loss: 2.6007
# Epoch 52/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0343 - val_loss: 2.5552
# Epoch 53/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0336 - val_loss: 2.6470
# Epoch 54/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0327 - val_loss: 2.5668
# Epoch 55/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0319 - val_loss: 2.5615
# Epoch 56/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0308 - val_loss: 2.5486
# Epoch 57/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0302 - val_loss: 2.6014
# Epoch 58/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0296 - val_loss: 2.5010
# Epoch 59/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0289 - val_loss: 2.5726
# Epoch 60/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0283 - val_loss: 2.5040
# Epoch 61/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0277 - val_loss: 2.6235
# Epoch 62/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0274 - val_loss: 2.5716
# Epoch 63/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0268 - val_loss: 2.6491
# Epoch 64/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0261 - val_loss: 2.5574
# Epoch 65/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0256 - val_loss: 2.5909
# Epoch 66/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0251 - val_loss: 2.5835
# Epoch 67/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0244 - val_loss: 2.6346
# Epoch 68/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0242 - val_loss: 2.5577
# Epoch 69/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0235 - val_loss: 2.5988
# Epoch 70/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0231 - val_loss: 2.5577
# Epoch 71/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0223 - val_loss: 2.5873
# Epoch 72/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0221 - val_loss: 2.5558
# Epoch 73/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0216 - val_loss: 2.5685
# Epoch 74/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0212 - val_loss: 2.5565
# Epoch 75/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0207 - val_loss: 2.6848
# Epoch 76/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0203 - val_loss: 2.6279
# Epoch 77/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0205 - val_loss: 2.6836
# Epoch 78/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0199 - val_loss: 2.6459
# Epoch 79/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0195 - val_loss: 2.7225
# Epoch 80/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0190 - val_loss: 2.5807
# Epoch 81/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0183 - val_loss: 2.6564
# Epoch 82/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0182 - val_loss: 2.6372
# Epoch 83/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0177 - val_loss: 2.6794
# Epoch 84/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0173 - val_loss: 2.6159
# Epoch 85/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0170 - val_loss: 2.6650
# Epoch 86/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0167 - val_loss: 2.6187
# Epoch 87/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0165 - val_loss: 2.7057
# Epoch 88/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0163 - val_loss: 2.6315
# Epoch 89/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0160 - val_loss: 2.7232
# Epoch 90/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0158 - val_loss: 2.6447
# Epoch 91/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0155 - val_loss: 2.7114
# Epoch 92/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0152 - val_loss: 2.6645
# Epoch 93/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0147 - val_loss: 2.7076
# Epoch 94/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0146 - val_loss: 2.6616
# Epoch 95/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0144 - val_loss: 2.7238
# Epoch 96/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0141 - val_loss: 2.6670
# Epoch 97/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0138 - val_loss: 2.7158
# Epoch 98/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0136 - val_loss: 2.7003
# Epoch 99/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0133 - val_loss: 2.7418
# Epoch 100/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0133 - val_loss: 2.6998

# %%
def _nwrmse(y_truth, y_pred, scaler_y):
    errors = []

    for i in range(y_truth.shape[0]):
        forecast_y_pred = scaler_y.inverse_transform(y_pred[i, :].ravel())
        forecast_y_truth = scaler_y.inverse_transform(y_truth[i, :].ravel())
        
        plt.plot(range(forecast_y_pred.shape[0]), forecast_y_pred, color='red')
        plt.plot(range(forecast_y_truth.shape[0]), forecast_y_truth, color='blue')
        
        
        count = forecast_y_pred.shape[0]
        weights = (3 * count - 2 * np.arange(1, count + 1) + 1) / (2 * count ** 2)
        error = np.sqrt(np.sum(((forecast_y_truth - forecast_y_pred) ** 2) * weights))
        mean_error = error / np.average(forecast_y_truth)
        errors.append(mean_error)

    return np.average(errors)

y_pred = model.predict(tx_test)
_nwrmse(ty_test, y_pred, scaler_y)
# Out:
# 1.0035120499177805

# %%
y_p = y_pred[-1, 0]
print(y_p.shape)
print(ty_test.shape)

plt.plot(np.arange(y_p.shape[0]), ty_test[-1, 0].ravel(), color='red')
plt.plot(np.arange(y_p.shape[0]), y_p, color='blue')
# Out:
# (59,)
# (2, 1, 59)
